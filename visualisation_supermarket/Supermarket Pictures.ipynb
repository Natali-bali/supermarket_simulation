# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw 
import numpy as np

# %%
im = Image.open('supermarket.png')
market = np.array(im)
print(market.shape, market.dtype)
# Out:
# (384, 576, 3) uint8

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=576x384 at 0x7FCE33C09DF0>

# %% [markdown]
# #### I will make another image with 4 locations and names for my visualisation

# %%
market = np.delete(market, np.arange(544,576), axis=1)

# %%
market.shape
# Out:
# (384, 544, 3)

# %%
blue_lines = market[0 : 32*13, 0:32*2]

# %%
Image.fromarray(blue_lines )
# Out:
# <PIL.Image.Image image mode=RGB size=64x384 at 0x7FCE34BD3970>

# %%
sriped_line = market[0 : 32*13, 5*32:5*32+32*3]

# %%
Image.fromarray(sriped_line)
# Out:
# <PIL.Image.Image image mode=RGB size=96x384 at 0x7FCE33C098E0>

# %%
market = np.append(market,sriped_line, axis=1)

# %%
market = np.append(market,blue_lines, axis=1)

# %%
market.shape
# Out:
# (384, 704, 3)

# %%
Image.fromarray(market)
# Out:
# <PIL.Image.Image image mode=RGB size=704x384 at 0x7FCE2F7A9E20>

# %%
blue_str = market[0 : 32, 0:14*32]

# %%
blue_str.shape
# Out:
# (32, 448, 3)

# %%
Image.fromarray(blue_str)
# Out:
# <PIL.Image.Image image mode=RGB size=448x32 at 0x7FCE34BD3340>

# %%
market[9*32:10*32, 4*32:18*32] = blue_str

# %%
market[8*32:9*32, 4*32:18*32] = blue_str

# %%
one_tile = market[2*32 : 3*32, 3*32:4*32]

# %%
market[1*32:2*32, 16*32:17*32] = one_tile

# %%
img = Image.fromarray(market)

# %%
draw = ImageDraw.Draw(img)
font = ImageFont.truetype("Banny-Round.ttf", 24)
draw.text((5*32, 0),"SUPERMARKET VISUALISATION",(255,255,255),font=font)

# %%
font = ImageFont.truetype("Banny-Round.ttf", 20)
draw.text((4*32, 1*32+4), "DIARY",  font=font, fill=255)
draw.text((8*32, 1*32+4), "FRUIT",  font=font, fill=255)
draw.text((12*32, 1*32+4), "DRINKS",  font=font, fill=255)
draw.text((16*32, 1*32+4), "SPICES",  font=font, fill=255)
draw.text((9*32, 10*32+4), "CHECKOUT",  font=font, fill=255)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=704x384 at 0x7FCE34BD33D0>

# %%
img.save('../pics/market_ready.png')

# %% [markdown]
# #### Get client picture

# %%
im_2 = Image.open('tiles.png')
tiles = np.array(im_2)

# %%
im_2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=516x288 at 0x7FCE34BB9A00>

# %%
cust = tiles[3*32:4*32, 0:32]

# %%
Image.fromarray(cust)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FCE34BB9160>

# %%
Image.fromarray(cust).save('../pics/customer.png')
